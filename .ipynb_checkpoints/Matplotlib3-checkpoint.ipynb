# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,20,0.5)
y = x**2

# %%
fig = plt.figure(figsize=(4,4), dpi=200)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y);

# %%
fig, axes = plt.subplots(2,1, figsize=(4,4), dpi=100)
axes[0].plot(x,y)
axes[0].set_title('Grafik 1')

axes[1].plot(x,y)
axes[1].set_title('Grafik 2')

plt.tight_layout()

plt.show()

# %%
fig.savefig('gambarku2.png', dpi=300)

# %% [markdown]
# # menambahkan legenda

# %%
fig = plt.figure(dpi=200)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label='Panngkat 2')
ax.plot(x,x**3, label='Pangkat 3')
ax.plot(x,x**4, label='Pangkat 4')

ax.legend()
plt.show()

# %%
fig = plt.figure(dpi=200)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, label='Panngkat 2', lw=3, ls='-', marker='o', marker)
ax.plot(x,x**3, label='Pangkat 3', lw=2, ls='--')
ax.plot(x,x**4, label='Pangkat 4',lw=3, ls='-.')

ax.legend()

plt.show()
