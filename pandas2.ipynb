# %% [markdown]
# # inspeksi data

# %%
import pandas as pd

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN

# %%
dataku.tail(18)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 873         0       3    male  47.0      0      0   9.0000        S  NaN
# 874         1       2  female  28.0      1      0  24.0000        C  NaN
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
# 876         0       3    male  20.0      0      0   9.8458        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows = 891

# %%
pd.options.display.min_rows
# Out:
# 891

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# 12          0       3    male  20.0      0      0    8.0500        S  NaN
# 13          0       3    male  39.0      1      5   31.2750        S  NaN
# 14          0       3  female  14.0      0      0    7.8542        S  NaN
# 15          1       2  female  55.0      0      0   16.0000        S  NaN
# 16          0       3    male   2.0      4      1   29.1250        Q  NaN
# 17          1       2    male   NaN      0      0   13.0000        S  NaN
# 18          0       3  female  31.0      1      0   18.0000        S  NaN
# 19          1       3  female   NaN      0      0    7.2250        C  NaN
# 20          0       2    male  35.0      0      0   26.0000        S  NaN
# 21          1       2    male  34.0      0      0   13.0000        S    D
# 22          1       3  female  15.0      0      0    8.0292        Q  NaN
# 23          1       1    male  28.0      0      0   35.5000        S    A
# 24          0       3  female   8.0      3      1   21.0750        S  NaN
# 25          1       3  female  38.0      1      5   31.3875        S  NaN
# 26          0       3    male   NaN      0      0    7.2250        C  NaN
# 27          0       1    male  19.0      3      2  263.0000        S    C
# 28          1       3  female   NaN      0      0    7.8792        Q  NaN
# 29          0       3    male   NaN      0      0    7.8958        S  NaN
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 861         0       2    male  21.0      1      0   11.5000        S  NaN
# 862         1       1  female  48.0      0      0   25.9292        S    D
# 863         0       3  female   NaN      8      2   69.5500        S  NaN
# 864         0       2    male  24.0      0      0   13.0000        S  NaN
# 865         1       2  female  42.0      0      0   13.0000        S  NaN
# 866         1       2  female  27.0      1      0   13.8583        C  NaN
# 867         0       1    male  31.0      0      0   50.4958        S    A
# 868         0       3    male   NaN      0      0    9.5000        S  NaN
# 869         1       3    male   4.0      1      1   11.1333        S  NaN
# 870         0       3    male  26.0      0      0    7.8958        S  NaN
# 871         1       1  female  47.0      1      1   52.5542        S    D
# 872         0       1    male  33.0      0      0    5.0000        S    B
# 873         0       3    male  47.0      0      0    9.0000        S  NaN
# 874         1       2  female  28.0      1      0   24.0000        C  NaN
# 875         1       3  female  15.0      0      0    7.2250        C  NaN
# 876         0       3    male  20.0      0      0    9.8458        S  NaN
# 877         0       3    male  19.0      0      0    7.8958        S  NaN
# 878         0       3    male   NaN      0      0    7.8958        S  NaN
# 879         1       1  female  56.0      0      1   83.1583        C    C
# 880         1       2  female  25.0      0      1   26.0000        S  NaN
# 881         0       3    male  33.0      0      0    7.8958        S  NaN
# 882         0       3  female  22.0      0      0   10.5167        S  NaN
# 883         0       2    male  28.0      0      0   10.5000        S  NaN
# 884         0       3    male  25.0      0      0    7.0500        S  NaN
# 885         0       3  female  39.0      0      5   29.1250        Q  NaN
# 886         0       2    male  27.0      0      0   13.0000        S  NaN
# 887         1       1  female  19.0      0      0   30.0000        S    B
# 888         0       3  female   NaN      1      2   23.4500        S  NaN
# 889         1       1    male  26.0      0      0   30.0000        C    C
# 890         0       3    male  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
dataku.describe(include = "o")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 dataku.describe(include = "o")
#
# File D:\Anaconda\lib\site-packages\pandas\core\generic.py:10225, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9976 @final
#    9977 def describe(
#    9978     self: NDFrameT,
#    (...)
#    9982     datetime_is_numeric=False,
#    9983 ) -> NDFrameT:
#    9984     """
#    9985     Generate descriptive statistics.
#    9986
#    (...)
#   10223     max            NaN      3.0
#   10224     """
# > 10225     return describe_ndframe(
#   10226         obj=self,
#   10227         include=include,
#   10228         exclude=exclude,
#   10229         datetime_is_numeric=datetime_is_numeric,
#   10230         percentiles=percentiles,
#   10231     )
#
# File D:\Anaconda\lib\site-packages\pandas\core\describe.py:94, in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      86 else:
#      87     describer = DataFrameDescriber(
#      88         obj=cast("DataFrame", obj),
#      89         include=include,
#      90         exclude=exclude,
#      91         datetime_is_numeric=datetime_is_numeric,
#      92     )
# ---> 94 result = describer.describe(percentiles=percentiles)
#      95 return cast(NDFrameT, result)
#
# File D:\Anaconda\lib\site-packages\pandas\core\describe.py:169, in DataFrameDescriber.describe(self, percentiles)
#     168 def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 169     data = self._select_data()
#     171     ldesc: list[Series] = []
#     172     for _, series in data.items():
#
# File D:\Anaconda\lib\site-packages\pandas\core\describe.py:203, in DataFrameDescriber._select_data(self)
#     201     data = self.obj
#     202 else:
# --> 203     data = self.obj.select_dtypes(
#     204         include=self.include,
#     205         exclude=self.exclude,
#     206     )
#     207 return data
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:4351, in DataFrame.select_dtypes(self, include, exclude)
#    4348             converted_dtypes.append(infer_dtype_from_object(dtype))
#    4349     return frozenset(converted_dtypes)
# -> 4351 include = check_int_infer_dtype(include)
#    4352 exclude = check_int_infer_dtype(exclude)
#    4354 for dtypes in (include, exclude):
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:4348, in DataFrame.select_dtypes.<locals>.check_int_infer_dtype(dtypes)
#    4346         converted_dtypes.extend([np.float64, np.float32])
#    4347     else:
# -> 4348         converted_dtypes.append(infer_dtype_from_object(dtype))
#    4349 return frozenset(converted_dtypes)
#
# File D:\Anaconda\lib\site-packages\pandas\core\dtypes\common.py:1692, in infer_dtype_from_object(dtype)
#    1683     except (AttributeError, TypeError):
#    1684         # Handles cases like get_dtype(int) i.e.,
#    1685         # Python objects that are valid dtypes
#    (...)
#    1688         # TypeError handles the float16 type code of 'e'
#    1689         # further handle internal types
#    1690         pass
# -> 1692 return infer_dtype_from_object(np.dtype(dtype))
#
# TypeError: data type 'o' not understood
